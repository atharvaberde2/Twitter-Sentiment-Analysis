# %%
import pandas as pd

# %%
df = pd.read_csv('twitter_training.csv')

# %%
df = df.drop(columns = '2401')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74681 entries, 0 to 74680
# Data columns (total 3 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Borderlands                                            74681 non-null  object
#  1   Positive                                               74681 non-null  object
#  2   im getting on borderlands and i will murder you all ,  73995 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %%
df.dropna(subset=['Borderlands'], inplace=True)
df.dropna(subset=['Positive'], inplace=True)
df.dropna(subset=['im getting on borderlands and i will murder you all ,'], inplace=True)

# %%
df = df.drop(columns = 'Borderlands')

# %%
X = df.drop(columns = 'Positive')

# %%
Y = df['Positive']

# %%
Y.shape
# Out:
# (73995,)

# %%
import string
import re
import nltk
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer

# %%
stopwords = nltk.corpus.stopwords.words('English')
ps = nltk.PorterStemmer()

def clean_text(text):
    text = "".join([word for word in text if word not in string.punctuation])
    token = re.split('/W+', text)
    #text = [ps.stem(word) for word in token if word not in stopwords]
    return token

# %%
df['clean'] = df['im getting on borderlands and i will murder you all ,'].apply(lambda x: x.split(" "))

# %%
df['clean']
# Out:
# 0        [I, am, coming, to, the, borders, and, I, will...
# 1        [im, getting, on, borderlands, and, i, will, k...
# 2        [im, coming, on, borderlands, and, i, will, mu...
# 3        [im, getting, on, borderlands, 2, and, i, will...
# 4        [im, getting, into, borderlands, and, i, can, ...
#                                ...
# 74676    [Just, realized, that, the, Windows, partition...
# 74677    [Just, realized, that, my, Mac, window, partit...
# 74678    [Just, realized, the, windows, partition, of, ...
# 74679    [Just, realized, between, the, windows, partit...
# 74680    [Just, like, the, windows, partition, of, my, ...
# Name: clean, Length: 73995, dtype: object

# %%
def tokenize(text):
    clean_tokens = []
    for token in nlp(text):
        if (not token.is_stop) & (token.lemma_ != '-PRON-') & (not token.is_punct): # -PRON- is a special all inclusive "lemma" spaCy uses for any pronoun, we want to exclude these 
            clean_tokens.append(token.lemma_)
    return clean_tokens

# %%
import sklearn
import spacy
nlp = spacy.load("en_core_web_md")

from sklearn.feature_extraction.text import CountVectorizer
bow_transformer = CountVectorizer(analyzer=tokenize, max_features=800).fit(df['im getting on borderlands and i will murder you all ,'])

# %%
X = df['im getting on borderlands and i will murder you all ,']
X = bow_transformer.transform(X)

# %%
bow_transformer.vocabulary_
# Out:
# {'come': 236,
#  'kill': 444,
#  'm': 483,
#  'get': 371,
#  'borderland': 195,
#  '2': 12,
#  'spend': 674,
#  'hour': 420,
#  'make': 487,
#  'fun': 361,
#  'know': 447,
#  'huge': 423,
#  'fan': 333,
#  'favorite': 337,
#  'character': 222,
#  'decide': 280,
#  'pc': 550,
#  'original': 540,
#  'enjoy': 313,
#  'couple': 253,
#  'Borderlands': 54,
#  'picture': 561,
#  'pic.twitter.com': 558,
#  'rhandlerr': 622,
#  '3': 19,
#  'Xbox': 142,
#  ' ': 0,
#  '1': 5,
#  'live': 471,
#  'music': 517,
#  'e': 305,
#  'hard': 397,
#  'like': 464,
#  'long': 476,
#  'time': 713,
#  'actually': 152,
#  'experience': 324,
#  'good': 380,
#  'real': 603,
#  'nice': 522,
#  'wait': 751,
#  'hot': 419,
#  'row': 626,
#  'bad': 175,
#  'big': 187,
#  'life': 462,
#  'year': 788,
#  'ago': 155,
#  'fuck': 359,
#  'hang': 394,
#  'thank': 708,
#  'try': 729,
#  'stream': 687,
#  'tomorrow': 718,
#  'raid': 596,
#  'find': 345,
#  'yes': 789,
#  'maybe': 495,
#  'guy': 389,
#  '10': 6,
#  '4': 22,
#  'hey': 409,
#  'use': 741,
#  'Man': 94,
#  'need': 519,
#  'fix': 349,
#  'drop': 301,
#  'new': 520,
#  'not': 524,
#  'fine': 346,
#  '6': 25,
#  'suck': 692,
#  'completely': 241,
#  'day': 276,
#  'have': 399,
#  '<': 29,
#  'unk': 738,
#  '>': 31,
#  'force': 351,
#  'check': 226,
#  'epic': 316,
#  'streamer': 688,
#  'watch': 757,
#  'little': 470,
#  'bit': 189,
#  'got': 382,
#  'call': 210,
#  'early': 307,
#  'work': 775,
#  'sorry': 670,
#  'love': 480,
#  'morning': 514,
#  'twitch.tv': 734,
#  'man': 488,
#  'hear': 402,
#  'stupid': 691,
#  'country': 252,
#  'fall': 331,
#  't': 698,
#  'go': 377,
#  'finish': 347,
#  'today': 717,
#  'set': 648,
#  'look': 477,
#  'forward': 355,
#  'start': 677,
#  'event': 319,
#  '20': 13,
#  'awesome': 172,
#  'server': 646,
#  'probably': 583,
#  'play': 567,
#  'video': 748,
#  'chat': 224,
#  'chance': 220,
#  'w': 750,
#  'show': 654,
#  'UNK': 130,
#  'series': 644,
#  'movie': 516,
#  'hate': 398,
#  'easy': 309,
#  'will': 768,
#  'forever': 352,
#  'game': 365,
#  'add': 154,
#  'option': 538,
#  'turn': 730,
#  'terrible': 706,
#  'say': 634,
#  '9': 28,
#  'think': 710,
#  'win': 769,
#  'absolutely': 146,
#  'ridiculous': 623,
#  've': 745,
#  'take': 700,
#  'past': 547,
#  'send': 642,
#  'pretty': 580,
#  'cool': 251,
#  'despite': 289,
#  'die': 293,
#  'crap': 255,
#  'mobile': 509,
#  'annoying': 160,
#  'seriously': 645,
#  'appreciate': 163,
#  'talk': 702,
#  'action': 150,
#  'sound': 671,
#  'amazing': 157,
#  'create': 258,
#  'bring': 200,
#  'pay': 549,
#  'employee': 311,
#  'entire': 315,
#  'offer': 529,
#  'trash': 724,
#  'damn': 273,
#  'shit': 650,
#  'finally': 344,
#  'actual': 151,
#  'great': 384,
#  'feel': 340,
#  'story': 686,
#  'hand': 393,
#  'weapon': 759,
#  'funny': 362,
#  'open': 537,
#  '5': 23,
#  'sure': 695,
#  'oh': 531,
#  'Ghost': 79,
#  'want': 753,
#  'meet': 498,
#  'beautiful': 183,
#  'god': 378,
#  'hell': 405,
#  'month': 513,
#  'pull': 589,
#  'bitch': 190,
#  'ok': 532,
#  'hype': 424,
#  'give': 375,
#  'see': 640,
#  'case': 217,
#  'delete': 285,
#  'Overwatch': 107,
#  'mode': 510,
#  'switch': 696,
#  'lot': 479,
#  'reason': 605,
#  'run': 628,
#  'war': 754,
#  'high': 411,
#  'moment': 511,
#  'launch': 451,
#  'computer': 242,
#  'crash': 256,
#  'War': 135,
#  'break': 199,
#  'plus': 570,
#  'currently': 265,
#  'mind': 504,
#  'speed': 673,
#  'jump': 439,
#  'quality': 592,
#  'dumb': 303,
#  'internet': 433,
#  'lmao': 472,
#  'download': 298,
#  'enter': 314,
#  'step': 681,
#  'pic.wikipedia.org': 559,
#  'v': 743,
#  'update': 739,
#  'late': 449,
#  'broken': 202,
#  'rate': 599,
#  'low': 481,
#  'level': 460,
#  'possible': 573,
#  '+': 3,
#  'kinda': 446,
#  'push': 591,
#  'People': 111,
#  'move': 515,
#  'fast': 336,
#  'gold': 379,
#  'cut': 267,
#  'report': 614,
#  'rest': 615,
#  'fact': 328,
#  'photo': 556,
#  'tonight': 719,
#  'end': 312,
#  'allow': 156,
#  'well': 766,
#  'happy': 396,
#  'expect': 323,
#  'realize': 604,
#  'business': 207,
#  'problem': 584,
#  'far': 335,
#  'weekend': 763,
#  'old': 534,
#  'night': 523,
#  'close': 232,
#  'art': 164,
#  'piece': 562,
#  'follow': 350,
#  'load': 473,
#  'drive': 299,
#  'let': 459,
#  'pick': 560,
#  'League': 90,
#  'Super': 124,
#  'PlayStation': 113,
#  'New': 101,
#  's': 629,
#  'beat': 182,
#  'literally': 469,
#  'thing': 709,
#  'people': 551,
#  'girl': 374,
#  'fire': 348,
#  'credit': 259,
#  'to': 716,
#  'quit': 593,
#  'leave': 457,
#  'write': 780,
#  'r': 594,
#  'okay': 533,
#  'kind': 445,
#  '$': 2,
#  'Game': 77,
#  'PS4': 108,
#  'https': 422,
#  't.co': 699,
#  '11': 8,
#  'co': 233,
#  'Online': 105,
#  'welcome': 765,
#  'Best': 52,
#  'short': 652,
#  'second': 639,
#  'wonderful': 773,
#  'line': 465,
#  'player': 568,
#  'issue': 434,
#  'perfect': 552,
#  'important': 427,
#  'fantastic': 334,
#  'book': 194,
#  'patch': 548,
#  'power': 577,
#  'idea': 425,
#  'happen': 395,
#  'hi': 410,
#  'exactly': 320,
#  'review': 620,
#  'congratulation': 243,
#  '@playapex': 41,
#  '@CallofDuty': 32,
#  'family': 332,
#  'PlayApex': 112,
#  'special': 672,
#  'campaign': 211,
#  'cute': 268,
#  'tell': 705,
#  'post': 574,
#  'content': 247,
#  '19': 11,
#  'away': 171,
#  'believe': 184,
#  'Love': 92,
#  'rank': 598,
#  'Black': 53,
#  'word': 774,
#  'y': 785,
#  'star': 676,
#  'favourite': 338,
#  'screen': 636,
#  'title': 715,
#  'season': 638,
#  'pass': 546,
#  'store': 685,
#  'card': 215,
#  'final': 343,
#  'later': 450,
#  'access': 147,
#  'mission': 507,
#  'u': 736,
#  'console': 246,
#  'hit': 413,
#  '8': 27,
#  'stop': 684,
#  '7': 26,
#  'dead': 277,
#  'fucking': 360,
#  'friend': 358,
#  'recently': 607,
#  'Twitch': 127,
#  'RhandlerR': 119,
#  'continue': 248,
#  'home': 416,
#  'phone': 555,
#  'social': 667,
#  'medium': 497,
#  'head': 400,
#  'fight': 342,
#  'definitely': 283,
#  'right': 624,
#  'delay': 284,
#  'achievement': 149,
#  'understand': 737,
#  'com': 235,
#  'twice': 733,
#  'crazy': 257,
#  'way': 758,
#  'd': 271,
#  'money': 512,
#  'totally': 720,
#  '=': 30,
#  'feature': 339,
#  'online': 535,
#  'class': 229,
#  'xbox': 784,
#  'controller': 250,
#  'plan': 565,
#  'imagine': 426,
#  'pm': 571,
#  'powerful': 578,
#  'damage': 272,
#  'occur': 528,
#  'pic.facebook.com': 557,
#  'design': 288,
#  'week': 762,
#  'able': 144,
#  'anymore': 161,
#  'tired': 714,
#  '30': 20,
#  'tv': 731,
#  '\xa0': 797,
#  'product': 585,
#  'strong': 689,
#  'point': 572,
#  'detail': 291,
#  'ya': 786,
#  'excited': 321,
#  'GB': 75,
#  'main': 485,
#  'voice': 749,
#  'half': 392,
#  'yeah': 787,
#  'ass': 167,
#  'YouTube': 143,
#  'lose': 478,
#  'n': 518,
#  'block': 192,
#  'holy': 415,
#  'save': 633,
#  'x': 783,
#  'read': 601,
#  'face': 326,
#  'graphic': 383,
#  'dude': 302,
#  'deal': 278,
#  'fifa': 341,
#  '15': 10,
#  'gaming': 368,
#  'FIFA': 70,
#  'sale': 632,
#  'yesterday': 790,
#  'God': 81,
#  'miss': 506,
#  'forget': 353,
#  'g': 364,
#  'c': 209,
#  'worth': 778,
#  'battlefield': 180,
#  '0': 4,
#  'account': 148,
#  'return': 617,
#  'current': 264,
#  'FUCKING': 71,
#  'course': 254,
#  'major': 486,
#  'official': 530,
#  'super': 693,
#  'black': 191,
#  'heart': 403,
#  'lol': 475,
#  'small': 665,
#  'cause': 218,
#  'white': 767,
#  'mistake': 508,
#  'bc': 181,
#  'buy': 208,
#  'hope': 418,
#  'skin': 663,
#  'free': 357,
#  'log': 474,
#  'care': 216,
#  'garbage': 369,
#  'youtu.be': 794,
#  '@YouTube': 39,
#  'explain': 325,
#  'youtu': 793,
#  'wanna': 752,
#  'absolute': 145,
#  'song': 668,
#  'build': 205,
#  '2020': 14,
#  '|': 796,
#  'item': 435,
#  'child': 227,
#  'company': 239,
#  'simply': 658,
#  'Johnson': 88,
#  'market': 490,
#  'complete': 240,
#  'learn': 456,
#  'different': 294,
#  'version': 747,
#  'purchase': 590,
#  'system': 697,
#  'tho': 711,
#  'destroy': 290,
#  'change': 221,
#  'o': 527,
#  'pls': 569,
#  'ask': 166,
#  'help': 407,
#  'overwatch': 541,
#  'honestly': 417,
#  'recommend': 608,
#  'party': 545,
#  'community': 238,
#  'support': 694,
#  'incredible': 429,
#  'yo': 791,
#  'wrong': 781,
#  'safe': 631,
#  'matter': 494,
#  '12': 9,
#  'code': 234,
#  'bro': 201,
#  '21': 16,
#  'you': 792,
#  'random': 597,
#  'boy': 198,
#  'dog': 295,
#  'stuff': 690,
#  'school': 635,
#  'interesting': 432,
#  'match': 493,
#  'light': 463,
#  'sad': 630,
#  'Games': 78,
#  'mean': 496,
#  'exciting': 322,
#  'remember': 612,
#  'guess': 388,
#  'K': 89,
#  'join': 437,
#  'history': 412,
#  'ur': 740,
#  'brother': 203,
#  'stick': 682,
#  'GTA': 76,
#  'stay': 679,
#  'don': 296,
#  'job': 436,
#  'k': 440,
#  'WTF': 134,
#  '  ': 1,
#  'single': 659,
#  'team': 703,
#  'waste': 756,
#  'list': 467,
#  'wow': 779,
#  'kid': 443,
#  'box': 197,
#  'hold': 414,
#  'available': 170,
#  'Store': 123,
#  'link': 466,
#  'sit': 660,
#  '\u200d.': 798,
#  'base': 178,
#  'p': 542,
#  'World': 139,
#  'app': 162,
#  'gift': 373,
#  'receive': 606,
#  'wonder': 772,
#  'performance': 553,
#  'Red': 117,
#  'UK': 129,
#  'shut': 655,
#  'date': 274,
#  'mad': 484,
#  'number': 525,
#  'hello': 406,
#  'Pro': 114,
#  'price': 581,
#  'especially': 318,
#  'proud': 586,
#  'skill': 662,
#  'X': 141,
#  'red': 609,
#  'S': 120,
#  'ready': 602,
#  'website': 761,
#  'release': 611,
#  'order': 539,
#  'death': 279,
#  'Dead': 63,
#  'control': 249,
#  'future': 363,
#  'woman': 771,
#  'truly': 727,
#  'birthday': 188,
#  'news': 521,
#  'comment': 237,
#  'weird': 764,
#  'getting': 372,
#  'mention': 499,
#  '100': 7,
#  'share': 649,
#  'sport': 675,
#  'claim': 228,
#  'world': 777,
#  'include': 428,
#  'person': 554,
#  'sick': 656,
#  'massive': 492,
#  'shoot': 651,
#  'glad': 376,
#  'keep': 441,
#  'baby': 174,
#  'place': 564,
#  'connect': 244,
#  'cry': 261,
#  'attack': 169,
#  'soon': 669,
#  'Daily': 62,
#  'wear': 760,
#  'true': 726,
#  'throw': 712,
#  'remove': 613,
#  'gameplay': 366,
#  'car': 214,
#  'V': 132,
#  'Facebook': 72,
#  'joke': 438,
#  'cheat': 225,
#  'hacker': 391,
#  'sense': 643,
#  'test': 707,
#  'result': 616,
#  'clip': 231,
#  'hero': 408,
#  'instead': 431,
#  'gamer': 367,
#  'message': 500,
#  'Trump': 126,
#  'grow': 386,
#  'deserve': 287,
#  'decision': 281,
#  'franchise': 356,
#  'lag': 448,
#  'trailer': 723,
#  'wish': 770,
#  '50': 24,
#  'state': 678,
#  'house': 421,
#  'ad': 153,
#  'announce': 159,
#  'wtf': 782,
#  '2k': 18,
#  'fake': 330,
#  'map': 489,
#  'slow': 664,
#  'round': 625,
#  'EU': 69,
#  'Commission': 59,
#  'million': 502,
#  'poverty': 575,
#  'health': 401,
#  'service': 647,
#  'Wtf': 140,
#  'reveal': 619,
#  'piss': 563,
#  'Ops': 106,
#  'op': 536,
#  'boring': 196,
#  'Cold': 58,
#  'trust': 728,
#  'beta': 185,
#  'user': 742,
#  'bullshit': 206,
#  'pack': 543,
#  'pro': 582,
#  'smh': 666,
#  'click': 230,
#  'duty': 304,
#  'ruin': 627,
#  'Duty': 66,
#  'pre': 579,
#  'sell': 641,
#  'Twitter': 128,
#  'y’': 795,
#  'Canada': 57,
#  'listen': 468,
#  'hack': 390,
#  'Warzone': 137,
#  'battle': 179,
#  'challenge': 219,
#  'Google': 82,
#  'Ubisoft': 131,
#  'article': 165,
#  'b': 173,
#  'leak': 455,
#  'sign': 657,
#  'lie': 461,
#  'shot': 653,
#  'Italy': 87,
#  'blow': 193,
#  'tweet': 732,
#  'email': 310,
#  'developer': 292,
#  'luck': 482,
#  '🤣': 799,
#  'information': 430,
#  'PS5': 109,
#  'Microsoft': 95,
#  'page': 544,
#  'lead': 453,
#  'search': 637,
#  'Series': 121,
#  'Fortnite': 74,
#  'ball': 176,
#  'fail': 329,
#  'cuz': 269,
#  'platform': 566,
#  'racist': 595,
#  'site': 661,
#  'min': 503,
#  'minute': 505,
#  'cancel': 212,
#  'Windows': 138,
#  'Mobile': 96,
#  'steal': 680,
#  'amazon': 158,
#  'Amazon': 46,
#  'customer': 266,
#  'google': 381,
#  'Grand': 83,
#  'retweet': 618,
#  'reward': 621,
#  'Apple': 48,
#  'Home': 85,
#  'T': 125,
#  'earn': 308,
#  'Sony': 122,
#  '24': 17,
#  'mask': 491,
#  'tech': 704,
#  'India': 86,
#  'datum': 275,
#  'stock': 683,
#  'rating': 600,
#  'toxic': 722,
#  'News': 102,
#  'worker': 776,
#  'error': 317,
#  'driver': 300,
#  'charge': 223,
#  'twitter': 735,
#  'ban': 177,
#  'legend': 458,
#  'facebook': 327,
#  'league': 454,
#  'group': 385,
#  'Legends': 91,
#  'connection': 245,
#  'fortnite': 354,
#  'EA': 67,
#  'kick': 442,
#  'CS': 56,
#  'NBA': 98,
#  'gen': 370,
#  'RTX': 115,
#  'ps5': 587,
#  'cyberpunk': 270,
#  '2077': 15,
#  'Nvidia': 103,
#  'Verizon': 133,
#  'bug': 204,
#  '@NBA2': 36,
#  'NBA2': 99,
#  'N2': 97,
#  '3080': 21,
#  'nvidia': 526,
#  'microsoft': 501,
#  'Dota': 65,
#  '@Ronnie2': 37,
#  'AI': 44,
#  'Madden': 93,
#  'tournament': 721,
#  'dota': 297,
#  'gta': 387,
#  'Warcraft': 136,
#  'trial': 725,
#  'cs': 262,
#  'Battlefield': 51,
#  'Assassin': 49,
#  'Creed': 60,
#  'warcraft': 755,
#  'Achievement': 45,
#  'Hearthstone': 84,
#  'lawsuit': 452,
#  'deck': 282,
#  'csgo': 263,
#  'NVIDIA': 100,
#  'pubg': 588,
#  'PUBG': 110,
#  'Apex': 47,
#  'cancer': 213,
#  'assassin': 168,
#  'creed': 260,
#  'Assassins': 50,
#  'Odyssey': 104,
#  '@Ubisoft': 38,
#  '@rainbow6game': 42,
#  'Rainbow6Game': 116,
#  '@FortniteGame': 34,
#  'Fifa': 73,
#  'vaccine': 744,
#  'depot': 286,
#  'hearthstone': 404,
#  'DETAILS': 61,
#  'bf4db.com': 186,
#  'redemption': 610,
#  'Redemption': 118,
#  'verizon': 746,
#  '@verizon': 43,
#  'Depot': 64,
#  'powder': 576,
#  '@EAMaddenNFL': 33,
#  'eamaddennfl': 306,
#  'EAMaddenNFL': 68,
#  'talc': 701,
#  '@GhostRecon': 35,
#  'GhostRecon': 80,
#  '@ghostrecon': 40,
#  'Breakpoint': 55}

# %%
Y = Y.replace('Negative', 0)

# %%
import spacy
nlp = spacy.load("en_core_web_md")
doc = nlp(u"I like apples")
d= "I like apples"

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 P.toarray()
#
# NameError: name 'P' is not defined

# %%
Y = Y.replace('Positive', 1)

# %%
Y = Y.replace('Neutral', 2)

# %%
Y = Y.replace('Irrelevant', 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=101)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
X1_train, X1_test, y1_train, y1_test = train_test_split(X, Y, test_size=0.3, random_state=101, stratify = Y)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=600)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=600)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7985674707750524

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
lis = []
lrr= [1,2,3,6,8,16, 25, 45, 60, 100]
for i in lrr:
    model =  RandomForestClassifier(n_estimators = i).fit(X1_train,y1_train)
    lis.append(f1_score(y1_test, model.predict(X1_test), average = 'macro'))

# %%
import matplotlib.pyplot as plt
plt.plot(lrr,lis)

# %%
prediction = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score, roc_auc_score, f1_score
f1 = f1_score(y_test, prediction)
precision = precision_score(y_test, prediction)
recall = recall_score(y_test, prediction)
auc = roc_auc_score(y_test, prediction)

print("f1 for the model is: {}".format(f1))
print("Precision for the model is: {}".format(precision))
print("Recall for the model is: {}".format(recall))
print("AUC for the model is: {}".format(auc))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score, roc_auc_score, f1_score
# ----> 2 f1 = f1_score(y_test, prediction)
#       3 precision = precision_score(y_test, prediction)
#       4 recall = recall_score(y_test, prediction)
#
# File c:\Users\atber\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\atber\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1238, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1070 @validate_params(
#    1071     {
#    1072         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1096     zero_division="warn",
#    1097 ):
#    1098     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1099
#    1100     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1236     array([0.66666667, 1.        , 0.66666667])
#    1237     """
# -> 1238     return fbeta_score(
#    1239         y_true,
#    1240         y_pred,
#    1241         beta=1,
#    1242         labels=labels,
#    1243         pos_label=pos_label,
#    1244         average=average,
#    1245         sample_weight=sample_weight,
#    1246         zero_division=zero_division,
#    1247     )
#
# File c:\Users\atber\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File c:\Users\atber\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1411, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1250 @validate_params(
#    1251     {
#    1252         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1278     zero_division="warn",
#    1279 ):
#    1280     """Compute the F-beta score.
#    1281
#    1282     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1408     0.38...
#    1409     """
# -> 1411     _, _, f, _ = precision_recall_fscore_support(
#    1412         y_true,
#    1413         y_pred,
#    1414         beta=beta,
#    1415         labels=labels,
#    1416         pos_label=pos_label,
#    1417         average=average,
#    1418         warn_for=("f-score",),
#    1419         sample_weight=sample_weight,
#    1420         zero_division=zero_division,
#    1421     )
#    1422     return f
#
# File c:\Users\atber\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File c:\Users\atber\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1721, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1563 """Compute precision, recall, F-measure and support for each class.
#    1564
#    1565 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1718  array([2, 2, 2]))
#    1719 """
#    1720 zero_division_value = _check_zero_division(zero_division)
# -> 1721 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1723 # Calculate tp_sum, pred_sum, true_sum ###
#    1724 samplewise = average == "samples"
#
# File c:\Users\atber\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1516, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1514         if y_type == "multiclass":
#    1515             average_options.remove("samples")
# -> 1516         raise ValueError(
#    1517             "Target is %s but average='binary'. Please "
#    1518             "choose another average setting, one of %r." % (y_type, average_options)
#    1519         )
#    1520 elif pos_label not in (None, 1):
#    1521     warnings.warn(
#    1522         "Note that pos_label (set to %r) is ignored when "
#    1523         "average != 'binary' (got %r). You may use "
#    (...)
#    1526         UserWarning,
#    1527     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
# Out:
# 0.7926505069261447

# %%
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# 0.8793837421447395

# %% [markdown]
# pd.read_csv('twitter_validation')
